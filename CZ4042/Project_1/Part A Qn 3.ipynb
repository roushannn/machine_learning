# %%
import math
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior() 
import numpy as np
import pylab as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
import time
# Out:
# c:\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# c:\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING: Logging before flag parsing goes to stderr.
# W1013 22:06:28.610002 16056 deprecation.py:323] From c:\python37\lib\site-packages\tensorflow\python\compat\v2_compat.py:61: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# scale data
def scale(X, X_min, X_max):
    return (X - X_min)/(X_max-X_min)

NUM_FEATURES = 21
NUM_CLASSES = 3

learning_rate = 0.01
epochs = 2000
beta = 1e-6
batch_size = 16
num_neurons = [5,10,15,20,25]
seed = 10
np.random.seed(seed)

#read train data

train_input = np.genfromtxt('ctg_data_cleaned.csv', delimiter= ',')
trainX, train_Y = train_input[1:, :21], train_input[1:,-1].astype(int)
#split dataset in 70:30
X_train, X_test, Ytrain, Ytest = train_test_split(trainX, train_Y, test_size=0.3, random_state=20, shuffle=True)

X_train = scale(X_train, np.min(X_train, axis=0), np.max(X_train, axis=0))
X_test = scale(X_test, np.min(X_test, axis=0), np.max(X_test, axis=0))

Y_train = np.zeros((Ytrain.shape[0], NUM_CLASSES))
Y_train[np.arange(Ytrain.shape[0]), Ytrain-1] = 1 #one hot matrix

Y_test = np.zeros((Ytest.shape[0], NUM_CLASSES))
Y_test[np.arange(Ytest.shape[0]), Ytest-1] = 1 #one hot matrix

n = X_train.shape[0]
    
# Create the model
x = tf.placeholder(tf.float32, [None, NUM_FEATURES])
y_ = tf.placeholder(tf.float32, [None, NUM_CLASSES])

# %%
kf = KFold(n_splits=5, random_state=20, shuffle=True)
N = len(X_train)

acc_fold = []
mean_acc_neuron = []
totalmean_acc_neuron = []
for n in num_neurons:
    # Build the graph for the deep net
	
    #Build 1st layer to hidden layer
    weights_to_h = tf.Variable(tf.truncated_normal([NUM_FEATURES, n], stddev=1.0/math.sqrt(float(NUM_FEATURES))), name='weights_to_h')
    biases_to_h  = tf.Variable(tf.zeros([n]), name='biases_to_h')
    hidden1 = tf.nn.relu(tf.matmul(x, weights_to_h) + biases_to_h)

    #Build 2nd layer to output layer (softmax layer)
    weights_to_o = tf.Variable(tf.truncated_normal([NUM_FEATURES, NUM_CLASSES], stddev=1.0/math.sqrt(float(NUM_FEATURES))), name='weights_to_o')
    biases_to_o  = tf.Variable(tf.zeros([NUM_CLASSES]), name='biases_to_o')
    logits  = tf.matmul(x, weights_to_o) + biases_to_o

    #L2 regularization with weight decay
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(labels=y_, logits=logits)
    regularization = tf.nn.l2_loss(weights_to_h) + tf.nn.l2_loss(weights_to_o)
    loss = tf.reduce_mean(cross_entropy + beta*regularization)

    # Create the gradient descent optimizer with the given learning rate.
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    train_op = optimizer.minimize(loss)

    correct_prediction = tf.cast(tf.equal(tf.argmax(logits, 1), tf.argmax(y_, 1)), tf.float32)
    accuracy = tf.reduce_mean(correct_prediction)
    
    print("Number of neurons: " + str(n))
    fold = 1
    acc_fold = []
    for train_index, test_index in kf.split(X_train):
        #print("TRAIN:", train_index, "TEST:", test_index)
        print("Fold number: " + str(fold))
        X_traink, X_testk = X_train[train_index], X_train[test_index]
        Y_traink, Y_testk = Y_train[train_index], Y_train[test_index]
        
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            train_acc = []
            test_acc = []

            for i in range(epochs):
                
                for start, end in zip(range(0, N, batch_size), range(batch_size, N, batch_size)):
                    train_op.run(feed_dict={x: X_traink[start:end], y_: Y_traink[start:end]})

                train_acc.append(accuracy.eval(feed_dict={x: X_traink, y_: Y_traink}))
                test_acc.append(accuracy.eval(feed_dict={x: X_testk, y_: Y_testk}))

                if i % 100 == 0:
                    print('iter %d: Train accuracy %g'%(i, train_acc[i]))
                    print('iter %d: Test accuracy %g'%(i, test_acc[i]))
            
        #store accuracy of each fold
        acc_fold.append(test_acc)
        fold += 1

    #find mean accuracy of each batch
    mean_acc = np.mean(np.array(acc_fold), axis=0)
    mean_acc_neuron.append(mean_acc)
    
    #find total mean accuracy of each batch
    totalmean_acc = np.mean(np.array(mean_acc_neuron), axis=0)
    totalmean_acc_neuron.append(totalmean_acc.mean())
    
           
# 2a) plot CV accuracy against number of epochs for different batch size           
plt.figure(1)
plt.plot(range(epochs), mean_acc_neuron[0], label = "5 Neurons")
plt.plot(range(epochs), mean_acc_neuron[1], label = "10 Neurons")
plt.plot(range(epochs), mean_acc_neuron[2], label = "15 Neurons")
plt.plot(range(epochs), mean_acc_neuron[3], label = "20 Neurons")
plt.plot(range(epochs), mean_acc_neuron[4], label = "25 Neurons")
plt.xlabel(str(epochs) + ' Epochs')
plt.ylabel('Cross Validation Accuracy')
plt.legend()
plt.show()
# Out:
# Number of neurons: 5
# Fold number: 1
# iter 0: Train accuracy 0.794118
# iter 0: Test accuracy 0.785235
# iter 100: Train accuracy 0.85042
# iter 100: Test accuracy 0.838926
# iter 200: Train accuracy 0.868067
# iter 200: Test accuracy 0.869128
# iter 300: Train accuracy 0.884034
# iter 300: Test accuracy 0.889262
# iter 400: Train accuracy 0.889916
# iter 400: Test accuracy 0.899329
# iter 500: Train accuracy 0.894118
# iter 500: Test accuracy 0.895973
# iter 600: Train accuracy 0.897479
# iter 600: Test accuracy 0.899329
# iter 700: Train accuracy 0.896639
# iter 700: Test accuracy 0.895973
# iter 800: Train accuracy 0.898319
# iter 800: Test accuracy 0.895973
# iter 900: Train accuracy 0.90084
# iter 900: Test accuracy 0.892617
# iter 1000: Train accuracy 0.9
# iter 1000: Test accuracy 0.895973
# iter 1100: Train accuracy 0.90084
# iter 1100: Test accuracy 0.892617
# iter 1200: Train accuracy 0.902521
# iter 1200: Test accuracy 0.892617
# iter 1300: Train accuracy 0.902521
# iter 1300: Test accuracy 0.892617
# iter 1400: Train accuracy 0.902521
# iter 1400: Test accuracy 0.889262
# iter 1500: Train accuracy 0.902521
# iter 1500: Test accuracy 0.889262
# iter 1600: Train accuracy 0.902521
# iter 1600: Test accuracy 0.889262
# iter 1700: Train accuracy 0.902521
# iter 1700: Test accuracy 0.885906
# iter 1800: Train accuracy 0.902521
# iter 1800: Test accuracy 0.885906
# iter 1900: Train accuracy 0.904202
# iter 1900: Test accuracy 0.889262
# Fold number: 2
# iter 0: Train accuracy 0.781513
# iter 0: Test accuracy 0.83557
# iter 100: Train accuracy 0.852101
# iter 100: Test accuracy 0.865772
# iter 200: Train accuracy 0.877311
# iter 200: Test accuracy 0.869128
# iter 300: Train accuracy 0.884034
# iter 300: Test accuracy 0.879195
# iter 400: Train accuracy 0.887395
# iter 400: Test accuracy 0.885906
# iter 500: Train accuracy 0.894118
# iter 500: Test accuracy 0.892617
# iter 600: Train accuracy 0.893277
# iter 600: Test accuracy 0.895973
# iter 700: Train accuracy 0.893277
# iter 700: Test accuracy 0.899329
# iter 800: Train accuracy 0.894958
# iter 800: Test accuracy 0.899329
# iter 900: Train accuracy 0.895798
# iter 900: Test accuracy 0.899329
# iter 1000: Train accuracy 0.896639
# iter 1000: Test accuracy 0.899329
# iter 1100: Train accuracy 0.898319
# iter 1100: Test accuracy 0.899329
# iter 1200: Train accuracy 0.90084
# iter 1200: Test accuracy 0.899329
# iter 1300: Train accuracy 0.901681
# iter 1300: Test accuracy 0.899329
# iter 1400: Train accuracy 0.903361
# iter 1400: Test accuracy 0.899329
# iter 1500: Train accuracy 0.903361
# iter 1500: Test accuracy 0.899329
# iter 1600: Train accuracy 0.903361
# iter 1600: Test accuracy 0.899329
# iter 1700: Train accuracy 0.903361
# iter 1700: Test accuracy 0.899329
# iter 1800: Train accuracy 0.905042
# iter 1800: Test accuracy 0.899329
# iter 1900: Train accuracy 0.906723
# iter 1900: Test accuracy 0.899329
# Fold number: 3
# iter 0: Train accuracy 0.791597
# iter 0: Test accuracy 0.795302
# iter 100: Train accuracy 0.842017
# iter 100: Test accuracy 0.875839
# iter 200: Train accuracy 0.872269
# iter 200: Test accuracy 0.889262
# iter 300: Train accuracy 0.880672
# iter 300: Test accuracy 0.889262
# iter 400: Train accuracy 0.886555
# iter 400: Test accuracy 0.899329
# iter 500: Train accuracy 0.889076
# iter 500: Test accuracy 0.899329
# iter 600: Train accuracy 0.891597
# iter 600: Test accuracy 0.899329
# iter 700: Train accuracy 0.890756
# iter 700: Test accuracy 0.902685
# iter 800: Train accuracy 0.892437
# iter 800: Test accuracy 0.90604
# iter 900: Train accuracy 0.894958
# iter 900: Test accuracy 0.902685
# iter 1000: Train accuracy 0.896639
# iter 1000: Test accuracy 0.902685
# iter 1100: Train accuracy 0.896639
# iter 1100: Test accuracy 0.899329
# iter 1200: Train accuracy 0.897479
# iter 1200: Test accuracy 0.902685
# iter 1300: Train accuracy 0.89916
# iter 1300: Test accuracy 0.902685
# iter 1400: Train accuracy 0.89916
# iter 1400: Test accuracy 0.90604
# iter 1500: Train accuracy 0.9
# iter 1500: Test accuracy 0.909396
# iter 1600: Train accuracy 0.9
# iter 1600: Test accuracy 0.90604
# iter 1700: Train accuracy 0.9
# iter 1700: Test accuracy 0.90604
# iter 1800: Train accuracy 0.89916
# iter 1800: Test accuracy 0.90604
# iter 1900: Train accuracy 0.90084
# iter 1900: Test accuracy 0.90604
# Fold number: 4
# iter 0: Train accuracy 0.793451
# iter 0: Test accuracy 0.784512
# iter 100: Train accuracy 0.853904
# iter 100: Test accuracy 0.83165
# iter 200: Train accuracy 0.879093
# iter 200: Test accuracy 0.858586
# iter 300: Train accuracy 0.883291
# iter 300: Test accuracy 0.868687
# iter 400: Train accuracy 0.893367
# iter 400: Test accuracy 0.868687
# iter 500: Train accuracy 0.900084
# iter 500: Test accuracy 0.868687
# iter 600: Train accuracy 0.898405
# iter 600: Test accuracy 0.868687
# iter 700: Train accuracy 0.897565
# iter 700: Test accuracy 0.872054
# iter 800: Train accuracy 0.900084
# iter 800: Test accuracy 0.875421
# iter 900: Train accuracy 0.900924
# iter 900: Test accuracy 0.875421
# iter 1000: Train accuracy 0.900924
# iter 1000: Test accuracy 0.872054
# iter 1100: Train accuracy 0.901763
# iter 1100: Test accuracy 0.872054
# iter 1200: Train accuracy 0.903443
# iter 1200: Test accuracy 0.875421
# iter 1300: Train accuracy 0.904282
# iter 1300: Test accuracy 0.878788
# iter 1400: Train accuracy 0.904282
# iter 1400: Test accuracy 0.875421
# iter 1500: Train accuracy 0.903443
# iter 1500: Test accuracy 0.875421
# iter 1600: Train accuracy 0.902603
# iter 1600: Test accuracy 0.878788
# iter 1700: Train accuracy 0.901763
# iter 1700: Test accuracy 0.878788
# iter 1800: Train accuracy 0.902603
# iter 1800: Test accuracy 0.882155
# iter 1900: Train accuracy 0.901763
# iter 1900: Test accuracy 0.882155
# Fold number: 5
# iter 0: Train accuracy 0.800168
# iter 0: Test accuracy 0.760943
# iter 100: Train accuracy 0.849706
# iter 100: Test accuracy 0.818182
# iter 200: Train accuracy 0.879093
# iter 200: Test accuracy 0.858586
# iter 300: Train accuracy 0.889169
# iter 300: Test accuracy 0.872054
# iter 400: Train accuracy 0.895886
# iter 400: Test accuracy 0.878788
# iter 500: Train accuracy 0.895046
# iter 500: Test accuracy 0.878788
# iter 600: Train accuracy 0.896725
# iter 600: Test accuracy 0.882155
# iter 700: Train accuracy 0.897565
# iter 700: Test accuracy 0.878788
# iter 800: Train accuracy 0.897565
# iter 800: Test accuracy 0.878788
# iter 900: Train accuracy 0.899244
# iter 900: Test accuracy 0.882155
# iter 1000: Train accuracy 0.901763
# iter 1000: Test accuracy 0.882155
# iter 1100: Train accuracy 0.902603
# iter 1100: Test accuracy 0.885522
# iter 1200: Train accuracy 0.901763
# iter 1200: Test accuracy 0.885522
# iter 1300: Train accuracy 0.902603
# iter 1300: Test accuracy 0.885522
# iter 1400: Train accuracy 0.902603
# iter 1400: Test accuracy 0.888889
# iter 1500: Train accuracy 0.902603
# iter 1500: Test accuracy 0.888889
# iter 1600: Train accuracy 0.905122
# iter 1600: Test accuracy 0.888889
# iter 1700: Train accuracy 0.905122
# iter 1700: Test accuracy 0.888889
# iter 1800: Train accuracy 0.904282
# iter 1800: Test accuracy 0.888889
# iter 1900: Train accuracy 0.905961
# iter 1900: Test accuracy 0.888889
# Number of neurons: 10
# Fold number: 1
# iter 0: Train accuracy 0.794118
# iter 0: Test accuracy 0.785235
# iter 100: Train accuracy 0.852101
# iter 100: Test accuracy 0.838926
# iter 200: Train accuracy 0.872269
# iter 200: Test accuracy 0.869128
# iter 300: Train accuracy 0.883193
# iter 300: Test accuracy 0.895973
# iter 400: Train accuracy 0.889916
# iter 400: Test accuracy 0.899329
# iter 500: Train accuracy 0.889916
# iter 500: Test accuracy 0.895973
# iter 600: Train accuracy 0.894958
# iter 600: Test accuracy 0.895973
# iter 700: Train accuracy 0.897479
# iter 700: Test accuracy 0.895973
# iter 800: Train accuracy 0.89916
# iter 800: Test accuracy 0.892617
# iter 900: Train accuracy 0.90084
# iter 900: Test accuracy 0.892617
# iter 1000: Train accuracy 0.89916
# iter 1000: Test accuracy 0.892617
# iter 1100: Train accuracy 0.902521
# iter 1100: Test accuracy 0.895973
# iter 1200: Train accuracy 0.904202
# iter 1200: Test accuracy 0.895973
# iter 1300: Train accuracy 0.903361
# iter 1300: Test accuracy 0.892617
# iter 1400: Train accuracy 0.903361
# iter 1400: Test accuracy 0.892617
# iter 1500: Train accuracy 0.905882
# iter 1500: Test accuracy 0.889262
# iter 1600: Train accuracy 0.905042
# iter 1600: Test accuracy 0.889262
# iter 1700: Train accuracy 0.905042
# iter 1700: Test accuracy 0.889262
# iter 1800: Train accuracy 0.905882
# iter 1800: Test accuracy 0.892617
# iter 1900: Train accuracy 0.905042
# iter 1900: Test accuracy 0.892617
# Fold number: 2
# iter 0: Train accuracy 0.781513
# iter 0: Test accuracy 0.83557
# iter 100: Train accuracy 0.85042
# iter 100: Test accuracy 0.875839
# iter 200: Train accuracy 0.878992
# iter 200: Test accuracy 0.88255
# iter 300: Train accuracy 0.885714
# iter 300: Test accuracy 0.88255
# iter 400: Train accuracy 0.889076
# iter 400: Test accuracy 0.892617
# iter 500: Train accuracy 0.893277
# iter 500: Test accuracy 0.892617
# iter 600: Train accuracy 0.893277
# iter 600: Test accuracy 0.895973
# iter 700: Train accuracy 0.893277
# iter 700: Test accuracy 0.899329
# iter 800: Train accuracy 0.895798
# iter 800: Test accuracy 0.899329
# iter 900: Train accuracy 0.894958
# iter 900: Test accuracy 0.899329
# iter 1000: Train accuracy 0.896639
# iter 1000: Test accuracy 0.899329
# iter 1100: Train accuracy 0.898319
# iter 1100: Test accuracy 0.899329
# iter 1200: Train accuracy 0.901681
# iter 1200: Test accuracy 0.899329
# iter 1300: Train accuracy 0.902521
# iter 1300: Test accuracy 0.899329
# iter 1400: Train accuracy 0.902521
# iter 1400: Test accuracy 0.899329
# iter 1500: Train accuracy 0.903361
# iter 1500: Test accuracy 0.899329
# iter 1600: Train accuracy 0.902521
# iter 1600: Test accuracy 0.899329
# iter 1700: Train accuracy 0.902521
# iter 1700: Test accuracy 0.899329
# iter 1800: Train accuracy 0.903361
# iter 1800: Test accuracy 0.899329
# iter 1900: Train accuracy 0.905042
# iter 1900: Test accuracy 0.899329
# Fold number: 3
# iter 0: Train accuracy 0.791597
# iter 0: Test accuracy 0.795302
# iter 100: Train accuracy 0.843697
# iter 100: Test accuracy 0.872483
# iter 200: Train accuracy 0.876471
# iter 200: Test accuracy 0.892617
# iter 300: Train accuracy 0.881513
# iter 300: Test accuracy 0.889262
# iter 400: Train accuracy 0.886555
# iter 400: Test accuracy 0.895973
# iter 500: Train accuracy 0.889076
# iter 500: Test accuracy 0.895973
# iter 600: Train accuracy 0.889916
# iter 600: Test accuracy 0.895973
# iter 700: Train accuracy 0.890756
# iter 700: Test accuracy 0.902685
# iter 800: Train accuracy 0.893277
# iter 800: Test accuracy 0.902685
# iter 900: Train accuracy 0.894118
# iter 900: Test accuracy 0.902685
# iter 1000: Train accuracy 0.895798
# iter 1000: Test accuracy 0.902685
# iter 1100: Train accuracy 0.894958
# iter 1100: Test accuracy 0.899329
# iter 1200: Train accuracy 0.896639
# iter 1200: Test accuracy 0.899329
# iter 1300: Train accuracy 0.897479
# iter 1300: Test accuracy 0.902685
# iter 1400: Train accuracy 0.89916
# iter 1400: Test accuracy 0.902685
# iter 1500: Train accuracy 0.89916
# iter 1500: Test accuracy 0.902685
# iter 1600: Train accuracy 0.90084
# iter 1600: Test accuracy 0.902685
# iter 1700: Train accuracy 0.90084
# iter 1700: Test accuracy 0.902685
# iter 1800: Train accuracy 0.90084
# iter 1800: Test accuracy 0.902685
# iter 1900: Train accuracy 0.89916
# iter 1900: Test accuracy 0.902685
# Fold number: 4
# iter 0: Train accuracy 0.79429
# iter 0: Test accuracy 0.784512
# iter 100: Train accuracy 0.853065
# iter 100: Test accuracy 0.824916
# iter 200: Train accuracy 0.881612
# iter 200: Test accuracy 0.868687
# iter 300: Train accuracy 0.884131
# iter 300: Test accuracy 0.868687
# iter 400: Train accuracy 0.894207
# iter 400: Test accuracy 0.868687
# iter 500: Train accuracy 0.897565
# iter 500: Test accuracy 0.868687
# iter 600: Train accuracy 0.898405
# iter 600: Test accuracy 0.872054
# iter 700: Train accuracy 0.899244
# iter 700: Test accuracy 0.872054
# iter 800: Train accuracy 0.899244
# iter 800: Test accuracy 0.875421
# iter 900: Train accuracy 0.900924
# iter 900: Test accuracy 0.875421
# iter 1000: Train accuracy 0.900084
# iter 1000: Test accuracy 0.875421
# iter 1100: Train accuracy 0.902603
# iter 1100: Test accuracy 0.875421
# iter 1200: Train accuracy 0.904282
# iter 1200: Test accuracy 0.872054
# iter 1300: Train accuracy 0.905122
# iter 1300: Test accuracy 0.878788
# iter 1400: Train accuracy 0.904282
# iter 1400: Test accuracy 0.875421
# iter 1500: Train accuracy 0.904282
# iter 1500: Test accuracy 0.875421
# iter 1600: Train accuracy 0.903443
# iter 1600: Test accuracy 0.878788
# iter 1700: Train accuracy 0.903443
# iter 1700: Test accuracy 0.878788
# iter 1800: Train accuracy 0.900924
# iter 1800: Test accuracy 0.878788
# iter 1900: Train accuracy 0.901763
# iter 1900: Test accuracy 0.878788
# Fold number: 5
# iter 0: Train accuracy 0.800168
# iter 0: Test accuracy 0.760943
# iter 100: Train accuracy 0.850546
# iter 100: Test accuracy 0.814815
# iter 200: Train accuracy 0.875735
# iter 200: Test accuracy 0.861953
# iter 300: Train accuracy 0.888329
# iter 300: Test accuracy 0.875421
# iter 400: Train accuracy 0.894207
# iter 400: Test accuracy 0.875421
# iter 500: Train accuracy 0.896725
# iter 500: Test accuracy 0.878788
# iter 600: Train accuracy 0.893367
# iter 600: Test accuracy 0.878788
# iter 700: Train accuracy 0.895046
# iter 700: Test accuracy 0.875421
# iter 800: Train accuracy 0.896725
# iter 800: Test accuracy 0.878788
# iter 900: Train accuracy 0.898405
# iter 900: Test accuracy 0.882155
# iter 1000: Train accuracy 0.899244
# iter 1000: Test accuracy 0.882155
# iter 1100: Train accuracy 0.900084
# iter 1100: Test accuracy 0.885522
# iter 1200: Train accuracy 0.900924
# iter 1200: Test accuracy 0.885522
# iter 1300: Train accuracy 0.901763
# iter 1300: Test accuracy 0.885522
# iter 1400: Train accuracy 0.900924
# iter 1400: Test accuracy 0.885522
# iter 1500: Train accuracy 0.900924
# iter 1500: Test accuracy 0.888889
# iter 1600: Train accuracy 0.903443
# iter 1600: Test accuracy 0.888889
# iter 1700: Train accuracy 0.904282
# iter 1700: Test accuracy 0.888889
# iter 1800: Train accuracy 0.903443
# iter 1800: Test accuracy 0.888889
# iter 1900: Train accuracy 0.905122
# iter 1900: Test accuracy 0.888889
# Number of neurons: 15
# Fold number: 1
# iter 0: Train accuracy 0.794118
# iter 0: Test accuracy 0.785235
# iter 100: Train accuracy 0.85042
# iter 100: Test accuracy 0.842282
# iter 200: Train accuracy 0.873109
# iter 200: Test accuracy 0.865772
# iter 300: Train accuracy 0.886555
# iter 300: Test accuracy 0.895973
# iter 400: Train accuracy 0.889076
# iter 400: Test accuracy 0.895973
# iter 500: Train accuracy 0.894958
# iter 500: Test accuracy 0.899329
# iter 600: Train accuracy 0.897479
# iter 600: Test accuracy 0.895973
# iter 700: Train accuracy 0.896639
# iter 700: Test accuracy 0.895973
# iter 800: Train accuracy 0.895798
# iter 800: Test accuracy 0.892617
# iter 900: Train accuracy 0.9
# iter 900: Test accuracy 0.892617
# iter 1000: Train accuracy 0.9
# iter 1000: Test accuracy 0.892617
# iter 1100: Train accuracy 0.90084
# iter 1100: Test accuracy 0.895973
# iter 1200: Train accuracy 0.901681
# iter 1200: Test accuracy 0.892617
# iter 1300: Train accuracy 0.901681
# iter 1300: Test accuracy 0.889262
# iter 1400: Train accuracy 0.90084
# iter 1400: Test accuracy 0.889262
# iter 1500: Train accuracy 0.902521
# iter 1500: Test accuracy 0.885906
# iter 1600: Train accuracy 0.902521
# iter 1600: Test accuracy 0.889262
# iter 1700: Train accuracy 0.902521
# iter 1700: Test accuracy 0.889262
# iter 1800: Train accuracy 0.903361
# iter 1800: Test accuracy 0.892617
# iter 1900: Train accuracy 0.903361
# iter 1900: Test accuracy 0.892617
# Fold number: 2
# iter 0: Train accuracy 0.781513
# iter 0: Test accuracy 0.83557
# iter 100: Train accuracy 0.857983
# iter 100: Test accuracy 0.879195
# iter 200: Train accuracy 0.884034
# iter 200: Test accuracy 0.879195
# iter 300: Train accuracy 0.884874
# iter 300: Test accuracy 0.879195
# iter 400: Train accuracy 0.889916
# iter 400: Test accuracy 0.889262
# iter 500: Train accuracy 0.892437
# iter 500: Test accuracy 0.892617
# iter 600: Train accuracy 0.893277
# iter 600: Test accuracy 0.895973
# iter 700: Train accuracy 0.893277
# iter 700: Test accuracy 0.899329
# iter 800: Train accuracy 0.894118
# iter 800: Test accuracy 0.899329
# iter 900: Train accuracy 0.895798
# iter 900: Test accuracy 0.899329
# iter 1000: Train accuracy 0.895798
# iter 1000: Test accuracy 0.899329
# iter 1100: Train accuracy 0.898319
# iter 1100: Test accuracy 0.899329
# iter 1200: Train accuracy 0.9
# iter 1200: Test accuracy 0.899329
# iter 1300: Train accuracy 0.902521
# iter 1300: Test accuracy 0.899329
# iter 1400: Train accuracy 0.902521
# iter 1400: Test accuracy 0.899329
# iter 1500: Train accuracy 0.902521
# iter 1500: Test accuracy 0.899329
# iter 1600: Train accuracy 0.902521
# iter 1600: Test accuracy 0.899329
# iter 1700: Train accuracy 0.904202
# iter 1700: Test accuracy 0.899329
# iter 1800: Train accuracy 0.904202
# iter 1800: Test accuracy 0.899329
# iter 1900: Train accuracy 0.905042
# iter 1900: Test accuracy 0.899329
# Fold number: 3
# iter 0: Train accuracy 0.791597
# iter 0: Test accuracy 0.795302
# iter 100: Train accuracy 0.843697
# iter 100: Test accuracy 0.869128
# iter 200: Train accuracy 0.87563
# iter 200: Test accuracy 0.892617
# iter 300: Train accuracy 0.884874
# iter 300: Test accuracy 0.889262
# iter 400: Train accuracy 0.887395
# iter 400: Test accuracy 0.902685
# iter 500: Train accuracy 0.891597
# iter 500: Test accuracy 0.899329
# iter 600: Train accuracy 0.892437
# iter 600: Test accuracy 0.902685
# iter 700: Train accuracy 0.893277
# iter 700: Test accuracy 0.90604
# iter 800: Train accuracy 0.895798
# iter 800: Test accuracy 0.90604
# iter 900: Train accuracy 0.896639
# iter 900: Test accuracy 0.902685
# iter 1000: Train accuracy 0.895798
# iter 1000: Test accuracy 0.899329
# iter 1100: Train accuracy 0.894958
# iter 1100: Test accuracy 0.895973
# iter 1200: Train accuracy 0.896639
# iter 1200: Test accuracy 0.902685
# iter 1300: Train accuracy 0.897479
# iter 1300: Test accuracy 0.902685
# iter 1400: Train accuracy 0.89916
# iter 1400: Test accuracy 0.902685
# iter 1500: Train accuracy 0.898319
# iter 1500: Test accuracy 0.899329
# iter 1600: Train accuracy 0.89916
# iter 1600: Test accuracy 0.902685
# iter 1700: Train accuracy 0.89916
# iter 1700: Test accuracy 0.902685
# iter 1800: Train accuracy 0.898319
# iter 1800: Test accuracy 0.902685
# iter 1900: Train accuracy 0.903361
# iter 1900: Test accuracy 0.902685
# Fold number: 4
# iter 0: Train accuracy 0.793451
# iter 0: Test accuracy 0.784512
# iter 100: Train accuracy 0.842989
# iter 100: Test accuracy 0.835017
# iter 200: Train accuracy 0.876574
# iter 200: Test accuracy 0.858586
# iter 300: Train accuracy 0.88581
# iter 300: Test accuracy 0.86532
# iter 400: Train accuracy 0.892527
# iter 400: Test accuracy 0.868687
# iter 500: Train accuracy 0.899244
# iter 500: Test accuracy 0.872054
# iter 600: Train accuracy 0.900084
# iter 600: Test accuracy 0.872054
# iter 700: Train accuracy 0.899244
# iter 700: Test accuracy 0.875421
# iter 800: Train accuracy 0.900084
# iter 800: Test accuracy 0.875421
# iter 900: Train accuracy 0.900924
# iter 900: Test accuracy 0.875421
# iter 1000: Train accuracy 0.900924
# iter 1000: Test accuracy 0.872054
# iter 1100: Train accuracy 0.902603
# iter 1100: Test accuracy 0.872054
# iter 1200: Train accuracy 0.901763
# iter 1200: Test accuracy 0.872054
# iter 1300: Train accuracy 0.901763
# iter 1300: Test accuracy 0.878788
# iter 1400: Train accuracy 0.902603
# iter 1400: Test accuracy 0.875421
# iter 1500: Train accuracy 0.901763
# iter 1500: Test accuracy 0.875421
# iter 1600: Train accuracy 0.900924
# iter 1600: Test accuracy 0.875421
# iter 1700: Train accuracy 0.902603
# iter 1700: Test accuracy 0.875421
# iter 1800: Train accuracy 0.901763
# iter 1800: Test accuracy 0.875421
# iter 1900: Train accuracy 0.901763
# iter 1900: Test accuracy 0.878788
# Fold number: 5
# iter 0: Train accuracy 0.800168
# iter 0: Test accuracy 0.760943
# iter 100: Train accuracy 0.849706
# iter 100: Test accuracy 0.814815
# iter 200: Train accuracy 0.876574
# iter 200: Test accuracy 0.855219
# iter 300: Train accuracy 0.890008
# iter 300: Test accuracy 0.868687
# iter 400: Train accuracy 0.894207
# iter 400: Test accuracy 0.878788
# iter 500: Train accuracy 0.895046
# iter 500: Test accuracy 0.878788
# iter 600: Train accuracy 0.895046
# iter 600: Test accuracy 0.878788
# iter 700: Train accuracy 0.897565
# iter 700: Test accuracy 0.878788
# iter 800: Train accuracy 0.899244
# iter 800: Test accuracy 0.885522
# iter 900: Train accuracy 0.900924
# iter 900: Test accuracy 0.882155
# iter 1000: Train accuracy 0.900084
# iter 1000: Test accuracy 0.882155
# iter 1100: Train accuracy 0.900924
# iter 1100: Test accuracy 0.885522
# iter 1200: Train accuracy 0.900924
# iter 1200: Test accuracy 0.888889
# iter 1300: Train accuracy 0.900924
# iter 1300: Test accuracy 0.888889
# iter 1400: Train accuracy 0.900084
# iter 1400: Test accuracy 0.888889
# iter 1500: Train accuracy 0.900084
# iter 1500: Test accuracy 0.888889
# iter 1600: Train accuracy 0.904282
# iter 1600: Test accuracy 0.888889
# iter 1700: Train accuracy 0.904282
# iter 1700: Test accuracy 0.888889
# iter 1800: Train accuracy 0.904282
# iter 1800: Test accuracy 0.888889
# iter 1900: Train accuracy 0.905122
# iter 1900: Test accuracy 0.888889
# Number of neurons: 20
# Fold number: 1
# iter 0: Train accuracy 0.794118
# iter 0: Test accuracy 0.785235
# iter 100: Train accuracy 0.847899
# iter 100: Test accuracy 0.83557
# iter 200: Train accuracy 0.876471
# iter 200: Test accuracy 0.869128
# iter 300: Train accuracy 0.881513
# iter 300: Test accuracy 0.892617
# iter 400: Train accuracy 0.889916
# iter 400: Test accuracy 0.895973
# iter 500: Train accuracy 0.891597
# iter 500: Test accuracy 0.895973
# iter 600: Train accuracy 0.895798
# iter 600: Test accuracy 0.892617
# iter 700: Train accuracy 0.896639
# iter 700: Test accuracy 0.892617
# iter 800: Train accuracy 0.897479
# iter 800: Test accuracy 0.892617
# iter 900: Train accuracy 0.89916
# iter 900: Test accuracy 0.895973
# iter 1000: Train accuracy 0.90084
# iter 1000: Test accuracy 0.892617
# iter 1100: Train accuracy 0.902521
# iter 1100: Test accuracy 0.892617
# iter 1200: Train accuracy 0.902521
# iter 1200: Test accuracy 0.889262
# iter 1300: Train accuracy 0.905042
# iter 1300: Test accuracy 0.892617
# iter 1400: Train accuracy 0.905042
# iter 1400: Test accuracy 0.895973
# iter 1500: Train accuracy 0.905042
# iter 1500: Test accuracy 0.892617
# iter 1600: Train accuracy 0.904202
# iter 1600: Test accuracy 0.892617
# iter 1700: Train accuracy 0.905042
# iter 1700: Test accuracy 0.895973
# iter 1800: Train accuracy 0.905042
# iter 1800: Test accuracy 0.892617
# iter 1900: Train accuracy 0.905042
# iter 1900: Test accuracy 0.892617
# Fold number: 2
# iter 0: Train accuracy 0.785714
# iter 0: Test accuracy 0.83557
# iter 100: Train accuracy 0.855462
# iter 100: Test accuracy 0.872483
# iter 200: Train accuracy 0.884874
# iter 200: Test accuracy 0.885906
# iter 300: Train accuracy 0.884034
# iter 300: Test accuracy 0.88255
# iter 400: Train accuracy 0.888235
# iter 400: Test accuracy 0.889262
# iter 500: Train accuracy 0.892437
# iter 500: Test accuracy 0.895973
# iter 600: Train accuracy 0.893277
# iter 600: Test accuracy 0.899329
# iter 700: Train accuracy 0.893277
# iter 700: Test accuracy 0.899329
# iter 800: Train accuracy 0.895798
# iter 800: Test accuracy 0.899329
# iter 900: Train accuracy 0.895798
# iter 900: Test accuracy 0.899329
# iter 1000: Train accuracy 0.897479
# iter 1000: Test accuracy 0.899329
# iter 1100: Train accuracy 0.89916
# iter 1100: Test accuracy 0.899329
# iter 1200: Train accuracy 0.89916
# iter 1200: Test accuracy 0.899329
# iter 1300: Train accuracy 0.902521
# iter 1300: Test accuracy 0.902685
# iter 1400: Train accuracy 0.902521
# iter 1400: Test accuracy 0.902685
# iter 1500: Train accuracy 0.902521
# iter 1500: Test accuracy 0.902685
# iter 1600: Train accuracy 0.901681
# iter 1600: Test accuracy 0.902685
# iter 1700: Train accuracy 0.902521
# iter 1700: Test accuracy 0.902685
# iter 1800: Train accuracy 0.903361
# iter 1800: Test accuracy 0.902685
# iter 1900: Train accuracy 0.904202
# iter 1900: Test accuracy 0.902685
# Fold number: 3
# iter 0: Train accuracy 0.791597
# iter 0: Test accuracy 0.795302
# iter 100: Train accuracy 0.847899
# iter 100: Test accuracy 0.872483
# iter 200: Train accuracy 0.872269
# iter 200: Test accuracy 0.889262
# iter 300: Train accuracy 0.883193
# iter 300: Test accuracy 0.889262
# iter 400: Train accuracy 0.887395
# iter 400: Test accuracy 0.899329
# iter 500: Train accuracy 0.890756
# iter 500: Test accuracy 0.899329
# iter 600: Train accuracy 0.889916
# iter 600: Test accuracy 0.902685
# iter 700: Train accuracy 0.891597
# iter 700: Test accuracy 0.902685
# iter 800: Train accuracy 0.894118
# iter 800: Test accuracy 0.902685
# iter 900: Train accuracy 0.894958
# iter 900: Test accuracy 0.902685
# iter 1000: Train accuracy 0.896639
# iter 1000: Test accuracy 0.902685
# iter 1100: Train accuracy 0.896639
# iter 1100: Test accuracy 0.895973
# iter 1200: Train accuracy 0.897479
# iter 1200: Test accuracy 0.902685
# iter 1300: Train accuracy 0.898319
# iter 1300: Test accuracy 0.902685
# iter 1400: Train accuracy 0.9
# iter 1400: Test accuracy 0.902685
# iter 1500: Train accuracy 0.9
# iter 1500: Test accuracy 0.902685
# iter 1600: Train accuracy 0.9
# iter 1600: Test accuracy 0.90604
# iter 1700: Train accuracy 0.90084
# iter 1700: Test accuracy 0.90604
# iter 1800: Train accuracy 0.901681
# iter 1800: Test accuracy 0.90604
# iter 1900: Train accuracy 0.90084
# iter 1900: Test accuracy 0.90604
# Fold number: 4
# iter 0: Train accuracy 0.798489
# iter 0: Test accuracy 0.784512
# iter 100: Train accuracy 0.850546
# iter 100: Test accuracy 0.835017
# iter 200: Train accuracy 0.878254
# iter 200: Test accuracy 0.848485
# iter 300: Train accuracy 0.88665
# iter 300: Test accuracy 0.86532
# iter 400: Train accuracy 0.895046
# iter 400: Test accuracy 0.872054
# iter 500: Train accuracy 0.900084
# iter 500: Test accuracy 0.868687
# iter 600: Train accuracy 0.897565
# iter 600: Test accuracy 0.872054
# iter 700: Train accuracy 0.899244
# iter 700: Test accuracy 0.872054
# iter 800: Train accuracy 0.899244
# iter 800: Test accuracy 0.872054
# iter 900: Train accuracy 0.901763
# iter 900: Test accuracy 0.875421
# iter 1000: Train accuracy 0.902603
# iter 1000: Test accuracy 0.875421
# iter 1100: Train accuracy 0.903443
# iter 1100: Test accuracy 0.875421
# iter 1200: Train accuracy 0.902603
# iter 1200: Test accuracy 0.875421
# iter 1300: Train accuracy 0.902603
# iter 1300: Test accuracy 0.875421
# iter 1400: Train accuracy 0.902603
# iter 1400: Test accuracy 0.878788
# iter 1500: Train accuracy 0.900924
# iter 1500: Test accuracy 0.875421
# iter 1600: Train accuracy 0.901763
# iter 1600: Test accuracy 0.875421
# iter 1700: Train accuracy 0.900924
# iter 1700: Test accuracy 0.875421
# iter 1800: Train accuracy 0.900924
# iter 1800: Test accuracy 0.878788
# iter 1900: Train accuracy 0.902603
# iter 1900: Test accuracy 0.878788
# Fold number: 5
# iter 0: Train accuracy 0.800168
# iter 0: Test accuracy 0.760943
# iter 100: Train accuracy 0.848867
# iter 100: Test accuracy 0.814815
# iter 200: Train accuracy 0.879933
# iter 200: Test accuracy 0.858586
# iter 300: Train accuracy 0.888329
# iter 300: Test accuracy 0.872054
# iter 400: Train accuracy 0.895886
# iter 400: Test accuracy 0.875421
# iter 500: Train accuracy 0.895046
# iter 500: Test accuracy 0.878788
# iter 600: Train accuracy 0.896725
# iter 600: Test accuracy 0.878788
# iter 700: Train accuracy 0.895886
# iter 700: Test accuracy 0.878788
# iter 800: Train accuracy 0.900084
# iter 800: Test accuracy 0.878788
# iter 900: Train accuracy 0.900084
# iter 900: Test accuracy 0.882155
# iter 1000: Train accuracy 0.900084
# iter 1000: Test accuracy 0.885522
# iter 1100: Train accuracy 0.900924
# iter 1100: Test accuracy 0.885522
# iter 1200: Train accuracy 0.900924
# iter 1200: Test accuracy 0.885522
# iter 1300: Train accuracy 0.902603
# iter 1300: Test accuracy 0.888889
# iter 1400: Train accuracy 0.902603
# iter 1400: Test accuracy 0.888889
# iter 1500: Train accuracy 0.901763
# iter 1500: Test accuracy 0.888889
# iter 1600: Train accuracy 0.904282
# iter 1600: Test accuracy 0.888889
# iter 1700: Train accuracy 0.904282
# iter 1700: Test accuracy 0.888889
# iter 1800: Train accuracy 0.905122
# iter 1800: Test accuracy 0.888889
# iter 1900: Train accuracy 0.905122
# iter 1900: Test accuracy 0.888889
# Number of neurons: 25
# Fold number: 1
# iter 0: Train accuracy 0.794118
# iter 0: Test accuracy 0.785235
# iter 100: Train accuracy 0.85042
# iter 100: Test accuracy 0.832215
# iter 200: Train accuracy 0.87395
# iter 200: Test accuracy 0.869128
# iter 300: Train accuracy 0.884034
# iter 300: Test accuracy 0.892617
# iter 400: Train accuracy 0.890756
# iter 400: Test accuracy 0.895973
# iter 500: Train accuracy 0.895798
# iter 500: Test accuracy 0.892617
# iter 600: Train accuracy 0.897479
# iter 600: Test accuracy 0.892617
# iter 700: Train accuracy 0.9
# iter 700: Test accuracy 0.895973
# iter 800: Train accuracy 0.89916
# iter 800: Test accuracy 0.892617
# iter 900: Train accuracy 0.898319
# iter 900: Test accuracy 0.892617
# iter 1000: Train accuracy 0.90084
# iter 1000: Test accuracy 0.895973
# iter 1100: Train accuracy 0.902521
# iter 1100: Test accuracy 0.892617
# iter 1200: Train accuracy 0.902521
# iter 1200: Test accuracy 0.889262
# iter 1300: Train accuracy 0.901681
# iter 1300: Test accuracy 0.892617
# iter 1400: Train accuracy 0.901681
# iter 1400: Test accuracy 0.889262
# iter 1500: Train accuracy 0.903361
# iter 1500: Test accuracy 0.892617
# iter 1600: Train accuracy 0.903361
# iter 1600: Test accuracy 0.892617
# iter 1700: Train accuracy 0.903361
# iter 1700: Test accuracy 0.892617
# iter 1800: Train accuracy 0.904202
# iter 1800: Test accuracy 0.892617
# iter 1900: Train accuracy 0.904202
# iter 1900: Test accuracy 0.892617
# Fold number: 2
# iter 0: Train accuracy 0.781513
# iter 0: Test accuracy 0.83557
# iter 100: Train accuracy 0.856302
# iter 100: Test accuracy 0.88255
# iter 200: Train accuracy 0.880672
# iter 200: Test accuracy 0.879195
# iter 300: Train accuracy 0.883193
# iter 300: Test accuracy 0.88255
# iter 400: Train accuracy 0.888235
# iter 400: Test accuracy 0.885906
# iter 500: Train accuracy 0.890756
# iter 500: Test accuracy 0.892617
# iter 600: Train accuracy 0.892437
# iter 600: Test accuracy 0.895973
# iter 700: Train accuracy 0.893277
# iter 700: Test accuracy 0.899329
# iter 800: Train accuracy 0.893277
# iter 800: Test accuracy 0.899329
# iter 900: Train accuracy 0.894118
# iter 900: Test accuracy 0.899329
# iter 1000: Train accuracy 0.896639
# iter 1000: Test accuracy 0.899329
# iter 1100: Train accuracy 0.89916
# iter 1100: Test accuracy 0.899329
# iter 1200: Train accuracy 0.90084
# iter 1200: Test accuracy 0.899329
# iter 1300: Train accuracy 0.902521
# iter 1300: Test accuracy 0.899329
# iter 1400: Train accuracy 0.903361
# iter 1400: Test accuracy 0.899329
# iter 1500: Train accuracy 0.904202
# iter 1500: Test accuracy 0.899329
# iter 1600: Train accuracy 0.904202
# iter 1600: Test accuracy 0.899329
# iter 1700: Train accuracy 0.905042
# iter 1700: Test accuracy 0.899329
# iter 1800: Train accuracy 0.905882
# iter 1800: Test accuracy 0.899329
# iter 1900: Train accuracy 0.906723
# iter 1900: Test accuracy 0.895973
# Fold number: 3
# iter 0: Train accuracy 0.794118
# iter 0: Test accuracy 0.795302
# iter 100: Train accuracy 0.844538
# iter 100: Test accuracy 0.875839
# iter 200: Train accuracy 0.87395
# iter 200: Test accuracy 0.892617
# iter 300: Train accuracy 0.881513
# iter 300: Test accuracy 0.889262
# iter 400: Train accuracy 0.888235
# iter 400: Test accuracy 0.895973
# iter 500: Train accuracy 0.889076
# iter 500: Test accuracy 0.899329
# iter 600: Train accuracy 0.893277
# iter 600: Test accuracy 0.902685
# iter 700: Train accuracy 0.892437
# iter 700: Test accuracy 0.902685
# iter 800: Train accuracy 0.895798
# iter 800: Test accuracy 0.90604
# iter 900: Train accuracy 0.896639
# iter 900: Test accuracy 0.902685
# iter 1000: Train accuracy 0.897479
# iter 1000: Test accuracy 0.902685
# iter 1100: Train accuracy 0.897479
# iter 1100: Test accuracy 0.899329
# iter 1200: Train accuracy 0.898319
# iter 1200: Test accuracy 0.90604
# iter 1300: Train accuracy 0.89916
# iter 1300: Test accuracy 0.909396
# iter 1400: Train accuracy 0.9
# iter 1400: Test accuracy 0.909396
# iter 1500: Train accuracy 0.9
# iter 1500: Test accuracy 0.909396
# iter 1600: Train accuracy 0.89916
# iter 1600: Test accuracy 0.909396
# iter 1700: Train accuracy 0.898319
# iter 1700: Test accuracy 0.90604
# iter 1800: Train accuracy 0.90084
# iter 1800: Test accuracy 0.90604
# iter 1900: Train accuracy 0.89916
# iter 1900: Test accuracy 0.90604
# Fold number: 4
# iter 0: Train accuracy 0.79429
# iter 0: Test accuracy 0.784512
# iter 100: Train accuracy 0.853904
# iter 100: Test accuracy 0.838384
# iter 200: Train accuracy 0.879093
# iter 200: Test accuracy 0.858586
# iter 300: Train accuracy 0.882452
# iter 300: Test accuracy 0.86532
# iter 400: Train accuracy 0.892527
# iter 400: Test accuracy 0.868687
# iter 500: Train accuracy 0.897565
# iter 500: Test accuracy 0.868687
# iter 600: Train accuracy 0.895886
# iter 600: Test accuracy 0.868687
# iter 700: Train accuracy 0.897565
# iter 700: Test accuracy 0.875421
# iter 800: Train accuracy 0.897565
# iter 800: Test accuracy 0.875421
# iter 900: Train accuracy 0.898405
# iter 900: Test accuracy 0.875421
# iter 1000: Train accuracy 0.899244
# iter 1000: Test accuracy 0.872054
# iter 1100: Train accuracy 0.901763
# iter 1100: Test accuracy 0.872054
# iter 1200: Train accuracy 0.904282
# iter 1200: Test accuracy 0.872054
# iter 1300: Train accuracy 0.904282
# iter 1300: Test accuracy 0.878788
# iter 1400: Train accuracy 0.903443
# iter 1400: Test accuracy 0.878788
# iter 1500: Train accuracy 0.902603
# iter 1500: Test accuracy 0.875421
# iter 1600: Train accuracy 0.901763
# iter 1600: Test accuracy 0.875421
# iter 1700: Train accuracy 0.900924
# iter 1700: Test accuracy 0.875421
# iter 1800: Train accuracy 0.901763
# iter 1800: Test accuracy 0.875421
# iter 1900: Train accuracy 0.901763
# iter 1900: Test accuracy 0.878788
# Fold number: 5
# iter 0: Train accuracy 0.801008
# iter 0: Test accuracy 0.760943
# iter 100: Train accuracy 0.853904
# iter 100: Test accuracy 0.818182
# iter 200: Train accuracy 0.877414
# iter 200: Test accuracy 0.861953
# iter 300: Train accuracy 0.890848
# iter 300: Test accuracy 0.872054
# iter 400: Train accuracy 0.894207
# iter 400: Test accuracy 0.878788
# iter 500: Train accuracy 0.896725
# iter 500: Test accuracy 0.878788
# iter 600: Train accuracy 0.893367
# iter 600: Test accuracy 0.878788
# iter 700: Train accuracy 0.896725
# iter 700: Test accuracy 0.878788
# iter 800: Train accuracy 0.898405
# iter 800: Test accuracy 0.878788
# iter 900: Train accuracy 0.899244
# iter 900: Test accuracy 0.882155
# iter 1000: Train accuracy 0.901763
# iter 1000: Test accuracy 0.885522
# iter 1100: Train accuracy 0.902603
# iter 1100: Test accuracy 0.885522
# iter 1200: Train accuracy 0.900924
# iter 1200: Test accuracy 0.885522
# iter 1300: Train accuracy 0.900924
# iter 1300: Test accuracy 0.885522
# iter 1400: Train accuracy 0.901763
# iter 1400: Test accuracy 0.885522
# iter 1500: Train accuracy 0.901763
# iter 1500: Test accuracy 0.885522
# iter 1600: Train accuracy 0.900924
# iter 1600: Test accuracy 0.888889
# iter 1700: Train accuracy 0.903443
# iter 1700: Test accuracy 0.888889
# iter 1800: Train accuracy 0.903443
# iter 1800: Test accuracy 0.888889
# iter 1900: Train accuracy 0.904282
# iter 1900: Test accuracy 0.888889

# %%
# plot mean CV accuracy against no. of neurons
plt.figure(2)
plt.plot(range(len(num_neurons)), totalmean_acc_neuron)
plt.xticks(range(len(num_neurons)), num_neurons)
plt.xlabel('No. Of Neurons')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. No. Of Neurons')
# Out:
# Text(0.5, 1.0, 'Accuracy vs. No. Of Neurons')

# %%
# Build the graph for the deep net
#optimum num of hidden neurons = 5
	
#Build 1st layer to hidden layer
weights_to_h = tf.Variable(tf.truncated_normal([NUM_FEATURES, 5], stddev=1.0/math.sqrt(float(NUM_FEATURES))), name='weights_to_h')
biases_to_h  = tf.Variable(tf.zeros([5]), name='biases_to_h')
hidden1 = tf.nn.relu(tf.matmul(x, weights_to_h) + biases_to_h)

#Build 2nd layer to output layer (softmax layer)
weights_to_o = tf.Variable(tf.truncated_normal([NUM_FEATURES, NUM_CLASSES], stddev=1.0/math.sqrt(float(NUM_FEATURES))), name='weights_to_o')
biases_to_o  = tf.Variable(tf.zeros([NUM_CLASSES]), name='biases_to_o')
logits  = tf.matmul(x, weights_to_o) + biases_to_o

#L2 regularization with weight decay
cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(labels=y_, logits=logits)
regularization = tf.nn.l2_loss(weights_to_h) + tf.nn.l2_loss(weights_to_o)
loss = tf.reduce_mean(cross_entropy + beta*regularization)

# Create the gradient descent optimizer with the given learning rate.
optimizer = tf.train.GradientDescentOptimizer(learning_rate)
train_op = optimizer.minimize(loss)

correct_prediction = tf.cast(tf.equal(tf.argmax(logits, 1), tf.argmax(y_, 1)), tf.float32)
accuracy = tf.reduce_mean(correct_prediction)

fold = 1
acc_fold = []
for train_index, test_index in kf.split(X_train):
    print("Fold number: " + str(fold))
    X_traink, X_testk = X_train[train_index], X_train[test_index]
    Y_traink, Y_testk = Y_train[train_index], Y_train[test_index]

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        train_acc = []
        test_acc = []

        for i in range(epochs):
                
            for start, end in zip(range(0, N, batch_size), range(batch_size, N, batch_size)):
                train_op.run(feed_dict={x: X_traink[start:end], y_: Y_traink[start:end]})

            train_acc.append(accuracy.eval(feed_dict={x: X_traink, y_: Y_traink}))
            test_acc.append(accuracy.eval(feed_dict={x: X_testk, y_: Y_testk}))

            if i % 100 == 0:
                print('iter %d: Train accuracy %g'%(i, train_acc[i]))
                print('iter %d: Test accuracy %g'%(i, test_acc[i]))
# Out:
# Fold number: 1
# iter 0: Train accuracy 0.794118
# iter 0: Test accuracy 0.785235
# iter 100: Train accuracy 0.847059
# iter 100: Test accuracy 0.828859
# iter 200: Train accuracy 0.866387
# iter 200: Test accuracy 0.869128
# iter 300: Train accuracy 0.885714
# iter 300: Test accuracy 0.889262
# iter 400: Train accuracy 0.890756
# iter 400: Test accuracy 0.899329
# iter 500: Train accuracy 0.896639
# iter 500: Test accuracy 0.899329
# iter 600: Train accuracy 0.9
# iter 600: Test accuracy 0.895973
# iter 700: Train accuracy 0.898319
# iter 700: Test accuracy 0.892617
# iter 800: Train accuracy 0.898319
# iter 800: Test accuracy 0.892617
# iter 900: Train accuracy 0.89916
# iter 900: Test accuracy 0.892617
# iter 1000: Train accuracy 0.90084
# iter 1000: Test accuracy 0.895973
# iter 1100: Train accuracy 0.901681
# iter 1100: Test accuracy 0.895973
# iter 1200: Train accuracy 0.901681
# iter 1200: Test accuracy 0.895973
# iter 1300: Train accuracy 0.9
# iter 1300: Test accuracy 0.889262
# iter 1400: Train accuracy 0.90084
# iter 1400: Test accuracy 0.889262
# iter 1500: Train accuracy 0.90084
# iter 1500: Test accuracy 0.892617
# iter 1600: Train accuracy 0.903361
# iter 1600: Test accuracy 0.889262
# iter 1700: Train accuracy 0.904202
# iter 1700: Test accuracy 0.892617
# iter 1800: Train accuracy 0.904202
# iter 1800: Test accuracy 0.892617
# iter 1900: Train accuracy 0.904202
# iter 1900: Test accuracy 0.892617
# Fold number: 1
# iter 0: Train accuracy 0.781513
# iter 0: Test accuracy 0.83557
# iter 100: Train accuracy 0.854622
# iter 100: Test accuracy 0.869128
# iter 200: Train accuracy 0.879832
# iter 200: Test accuracy 0.885906
# iter 300: Train accuracy 0.882353
# iter 300: Test accuracy 0.88255
# iter 400: Train accuracy 0.888235
# iter 400: Test accuracy 0.889262
# iter 500: Train accuracy 0.889916
# iter 500: Test accuracy 0.895973
# iter 600: Train accuracy 0.892437
# iter 600: Test accuracy 0.899329
# iter 700: Train accuracy 0.894118
# iter 700: Test accuracy 0.899329
# iter 800: Train accuracy 0.894958
# iter 800: Test accuracy 0.899329
# iter 900: Train accuracy 0.895798
# iter 900: Test accuracy 0.899329
# iter 1000: Train accuracy 0.896639
# iter 1000: Test accuracy 0.899329
# iter 1100: Train accuracy 0.89916
# iter 1100: Test accuracy 0.902685
# iter 1200: Train accuracy 0.9
# iter 1200: Test accuracy 0.902685
# iter 1300: Train accuracy 0.904202
# iter 1300: Test accuracy 0.902685
# iter 1400: Train accuracy 0.904202
# iter 1400: Test accuracy 0.902685
# iter 1500: Train accuracy 0.903361
# iter 1500: Test accuracy 0.902685
# iter 1600: Train accuracy 0.902521
# iter 1600: Test accuracy 0.902685
# iter 1700: Train accuracy 0.903361
# iter 1700: Test accuracy 0.902685
# iter 1800: Train accuracy 0.903361
# iter 1800: Test accuracy 0.902685
# iter 1900: Train accuracy 0.905042
# iter 1900: Test accuracy 0.902685
# Fold number: 1
# iter 0: Train accuracy 0.791597
# iter 0: Test accuracy 0.795302
# iter 100: Train accuracy 0.847059
# iter 100: Test accuracy 0.872483
# iter 200: Train accuracy 0.871429
# iter 200: Test accuracy 0.892617
# iter 300: Train accuracy 0.884034
# iter 300: Test accuracy 0.889262
# iter 400: Train accuracy 0.888235
# iter 400: Test accuracy 0.895973
# iter 500: Train accuracy 0.888235
# iter 500: Test accuracy 0.899329
# iter 600: Train accuracy 0.893277
# iter 600: Test accuracy 0.902685
# iter 700: Train accuracy 0.892437
# iter 700: Test accuracy 0.902685
# iter 800: Train accuracy 0.892437
# iter 800: Test accuracy 0.90604
# iter 900: Train accuracy 0.894958
# iter 900: Test accuracy 0.902685
# iter 1000: Train accuracy 0.897479
# iter 1000: Test accuracy 0.899329
# iter 1100: Train accuracy 0.896639
# iter 1100: Test accuracy 0.899329
# iter 1200: Train accuracy 0.897479
# iter 1200: Test accuracy 0.90604
# iter 1300: Train accuracy 0.897479
# iter 1300: Test accuracy 0.90604
# iter 1400: Train accuracy 0.9
# iter 1400: Test accuracy 0.90604
# iter 1500: Train accuracy 0.9
# iter 1500: Test accuracy 0.90604
# iter 1600: Train accuracy 0.90084
# iter 1600: Test accuracy 0.909396
# iter 1700: Train accuracy 0.9
# iter 1700: Test accuracy 0.90604
# iter 1800: Train accuracy 0.89916
# iter 1800: Test accuracy 0.90604
# iter 1900: Train accuracy 0.90084
# iter 1900: Test accuracy 0.90604
# Fold number: 1
# iter 0: Train accuracy 0.79429
# iter 0: Test accuracy 0.784512
# iter 100: Train accuracy 0.851385
# iter 100: Test accuracy 0.838384
# iter 200: Train accuracy 0.878254
# iter 200: Test accuracy 0.86532
# iter 300: Train accuracy 0.882452
# iter 300: Test accuracy 0.86532
# iter 400: Train accuracy 0.890848
# iter 400: Test accuracy 0.868687
# iter 500: Train accuracy 0.899244
# iter 500: Test accuracy 0.868687
# iter 600: Train accuracy 0.897565
# iter 600: Test accuracy 0.868687
# iter 700: Train accuracy 0.897565
# iter 700: Test accuracy 0.872054
# iter 800: Train accuracy 0.897565
# iter 800: Test accuracy 0.875421
# iter 900: Train accuracy 0.899244
# iter 900: Test accuracy 0.878788
# iter 1000: Train accuracy 0.900924
# iter 1000: Test accuracy 0.875421
# iter 1100: Train accuracy 0.902603
# iter 1100: Test accuracy 0.872054
# iter 1200: Train accuracy 0.904282
# iter 1200: Test accuracy 0.875421
# iter 1300: Train accuracy 0.904282
# iter 1300: Test accuracy 0.878788
# iter 1400: Train accuracy 0.903443
# iter 1400: Test accuracy 0.878788
# iter 1500: Train accuracy 0.902603
# iter 1500: Test accuracy 0.878788
# iter 1600: Train accuracy 0.901763
# iter 1600: Test accuracy 0.875421
# iter 1700: Train accuracy 0.900924
# iter 1700: Test accuracy 0.875421
# iter 1800: Train accuracy 0.901763
# iter 1800: Test accuracy 0.875421
# iter 1900: Train accuracy 0.903443
# iter 1900: Test accuracy 0.878788
# Fold number: 1
# iter 0: Train accuracy 0.800168
# iter 0: Test accuracy 0.760943
# iter 100: Train accuracy 0.850546
# iter 100: Test accuracy 0.814815
# iter 200: Train accuracy 0.879933
# iter 200: Test accuracy 0.861953
# iter 300: Train accuracy 0.888329
# iter 300: Test accuracy 0.872054
# iter 400: Train accuracy 0.892527
# iter 400: Test accuracy 0.878788
# iter 500: Train accuracy 0.894207
# iter 500: Test accuracy 0.878788
# iter 600: Train accuracy 0.895886
# iter 600: Test accuracy 0.878788
# iter 700: Train accuracy 0.896725
# iter 700: Test accuracy 0.878788
# iter 800: Train accuracy 0.898405
# iter 800: Test accuracy 0.878788
# iter 900: Train accuracy 0.899244
# iter 900: Test accuracy 0.885522
# iter 1000: Train accuracy 0.900924
# iter 1000: Test accuracy 0.882155
# iter 1100: Train accuracy 0.900084
# iter 1100: Test accuracy 0.885522
# iter 1200: Train accuracy 0.900084
# iter 1200: Test accuracy 0.885522
# iter 1300: Train accuracy 0.900924
# iter 1300: Test accuracy 0.888889
# iter 1400: Train accuracy 0.901763
# iter 1400: Test accuracy 0.888889
# iter 1500: Train accuracy 0.901763
# iter 1500: Test accuracy 0.888889
# iter 1600: Train accuracy 0.903443
# iter 1600: Test accuracy 0.888889
# iter 1700: Train accuracy 0.905961
# iter 1700: Test accuracy 0.888889
# iter 1800: Train accuracy 0.906801
# iter 1800: Test accuracy 0.888889
# iter 1900: Train accuracy 0.905961
# iter 1900: Test accuracy 0.888889
# Text(0.5, 1.0, 'Training Accuracy vs. No. Of Epochs')

# %%
# plot training accuracy against no. of epochs
plt.figure(3)
plt.plot(range(epochs), train_acc, label = "Training Acc")
plt.plot(range(epochs), test_acc, label = "Testing Acc")
plt.xlabel('No. Of Epochs')
plt.ylabel('Accuracy')
plt.title('Num of Neurons = 5')
# Out:
# Text(0.5, 1.0, 'Num of Neurons = 5')
